# %% [markdown]
# <a href="https://colab.research.google.com/github/mrrajeev29/Exploratory-Data-Analysis-of-global-terrorism/blob/main/Global_Terrorism_colab_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Perform 'Exploratort Data Analysis' on dataset 'Global Terrorism'

# %% [markdown]
# # Task 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/drive/MyDrive/globalterrorismdb_0718dist.csv', encoding = 'latin1')
# Out:
# <ipython-input-2-d9eced2142c8>:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv('/content/drive/MyDrive/globalterrorismdb_0718dist.csv', encoding = 'latin1')

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
data.head(200)
# Out:
#           eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0    197000000001   1970       7     2        NaN         0        NaN
# 1    197000000002   1970       0     0        NaN         0        NaN
# 2    197001000001   1970       1     0        NaN         0        NaN
# 3    197001000002   1970       1     0        NaN         0        NaN
# 4    197001000003   1970       1     0        NaN         0        NaN
# ..            ...    ...     ...   ...        ...       ...        ...
# 195  197004150001   1970       4    15        NaN         0        NaN
# 196  197004150002   1970       4    15        NaN         0        NaN
# 197  197004150004   1970       4    15        NaN         0        NaN
# 198  197004150005   1970       4    15        NaN         0        NaN
# 199  197004160001   1970       4    16        NaN         0        NaN
#
#      country         country_txt  region  ...  \
# 0         58  Dominican Republic       2  ...
# 1        130              Mexico       1  ...
# 2        160         Philippines       5  ...
# 3         78              Greece       8  ...
# 4        101               Japan       4  ...
# ..       ...                 ...     ...  ...
# 195      102              Jordan      10  ...
# 196      217       United States       1  ...
# 197      217       United States       1  ...
# 198      217       United States       1  ...
# 199      217       United States       1  ...
#
#                                               addnotes  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 195                                                NaN
# 196                                                NaN
# 197  This is part of a multiple incident with 19700...
# 198  This is part of a multiple incident with 19700...
# 199  Part of a multiple attack with 197004160002 an...
#
#                                                 scite1  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 195                                                NaN
# 196  Committee on Government Operations United Stat...
# 197  "2 School Buildings Hit by Fires; Loss $95,000...
# 198  "2 School Buildings Hit by Fires; Loss $95,000...
# 199  Committee on Government Operations United Stat...
#
#                                                 scite2  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 195                                                NaN
# 196                                                NaN
# 197  Paul Houston and Franz Rodriguez, "Chicano Mil...
# 198  Paul Houston and Franz Rodriguez, "Chicano Mil...
# 199  "Teamster Walkouts Close More Plants," Washing...
#
#                                                 scite3        dbsource  \
# 0                                                  NaN            PGIS
# 1                                                  NaN            PGIS
# 2                                                  NaN            PGIS
# 3                                                  NaN            PGIS
# 4                                                  NaN            PGIS
# ..                                                 ...             ...
# 195                                                NaN            PGIS
# 196                                                NaN  Hewitt Project
# 197  "Two School Damaged by Early Fire," Lodi News-...  Hewitt Project
# 198  "Two School Damaged by Early Fire," Lodi News-...  Hewitt Project
# 199                                                NaN  Hewitt Project
#
#      INT_LOG  INT_IDEO INT_MISC INT_ANY  \
# 0          0         0        0       0
# 1          0         1        1       1
# 2         -9        -9        1       1
# 3         -9        -9        1       1
# 4         -9        -9        1       1
# ..       ...       ...      ...     ...
# 195        0         1        1       1
# 196        1         1        0       1
# 197        0         0        0       0
# 198        0         0        0       0
# 199       -9        -9        0      -9
#
#                                       related
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 195                                       NaN
# 196                                       NaN
# 197                197004150004, 197004150005
# 198                197004150004, 197004150005
# 199  197004160001, 197004160002, 197004160003
#
# [200 rows x 135 columns]

# %%
data.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [5 rows x 135 columns]

# %%
data.tail(20)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181671  201712310004   2017      12    31        NaN         0        NaN
# 181672  201712310005   2017      12    31        NaN         0        NaN
# 181673  201712310006   2017      12    31        NaN         0        NaN
# 181674  201712310007   2017      12    31        NaN         0        NaN
# 181675  201712310008   2017      12    31        NaN         0        NaN
# 181676  201712310009   2017      12    31        NaN         0        NaN
# 181677  201712310010   2017      12    31        NaN         0        NaN
# 181678  201712310011   2017      12    30        NaN         0        NaN
# 181679  201712310012   2017      12    31        NaN         0        NaN
# 181680  201712310013   2017      12    31        NaN         0        NaN
# 181681  201712310016   2017      12    31        NaN         0        NaN
# 181682  201712310017   2017      12    31        NaN         0        NaN
# 181683  201712310018   2017      12    31        NaN         0        NaN
# 181684  201712310019   2017      12    31        NaN         0        NaN
# 181685  201712310020   2017      12    31        NaN         0        NaN
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ...  \
# 181671       95         Iraq      10  ...
# 181672       92        India       6  ...
# 181673        4  Afghanistan       6  ...
# 181674       95         Iraq      10  ...
# 181675      182      Somalia      11  ...
# 181676        4  Afghanistan       6  ...
# 181677      160  Philippines       5  ...
# 181678      160  Philippines       5  ...
# 181679       95         Iraq      10  ...
# 181680      182      Somalia      11  ...
# 181681      160  Philippines       5  ...
# 181682       98        Italy       8  ...
# 181683        4  Afghanistan       6  ...
# 181684       92        India       6  ...
# 181685        4  Afghanistan       6  ...
# 181686      182      Somalia      11  ...
# 181687      200        Syria      10  ...
# 181688      160  Philippines       5  ...
# 181689       92        India       6  ...
# 181690      160  Philippines       5  ...
#
#                                                  addnotes  \
# 181671  Casualty numbers conflict across sources. Foll...
# 181672  The victims included Kuldip Roy, Taufail Ahmed...
# 181673  Casualty numbers conflict across sources. Foll...
# 181674                                                NaN
# 181675                                                NaN
# 181676  The victims included police commander Faqeer A...
# 181677                                                NaN
# 181678  The victims included the owner, Norodin Pacaln...
# 181679                                                NaN
# 181680                                                NaN
# 181681  The victims included Senior Police Officer 4 M...
# 181682                                                NaN
# 181683                                                NaN
# 181684                                                NaN
# 181685                                                NaN
# 181686                                                NaN
# 181687                                                NaN
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                                                    scite1  \
# 181671  "Islamic State attack leaves thirteen civilian...
# 181672  "Three soldiers killed in Indian-administered ...
# 181673  "Death toll from funeral blast in eastern Afgh...
# 181674  "Five IS militants killed as paramilitary troo...
# 181675  "Somalia: Al-Shabab says 5 AU soldiers dead in...
# 181676  "Commander among 5 ALP members killed in Logar...
# 181677  "3 slain in Maguindanao roadside bombings," Ph...
# 181678  "Cops hunt North Cotabato bombers," Philippine...
# 181679  "13 IS militants killed in attack on paramilit...
# 181680  "Somalia's al-Shabab fires mortars at Ethiopia...
# 181681  "3 dead, scores injured in Mindanao blasts," M...
# 181682  "Arson attack probed as racial crime," Ansa.it...
# 181683  "Six Members Of One Family Shot Dead In Faryab...
# 181684  "Abducted PSO rescued within 11 hours," The Se...
# 181685  "4 people injured in Farayb explosion," Pajhwo...
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 181671  "3 people killed in IS attack in central Iraq,...
# 181672  "Fidayeen used armour-piercing bullets in Leth...
# 181673  "The Latest: Toll from Afghan funeral bombing ...
# 181674  "1,262 Killed in Iraq During December," Antiwa...
# 181675  "Somalia: Fifteen Police Officers Complete Tra...
# 181676  "Media Highlights on Afghanistan 1 January 201...
# 181677  "BIFF gunmen torch abandoned houses in Maguind...
# 181678  "Philippines: Highlights of Terrorist, Counter...
# 181679                                                NaN
# 181680  "Somalia: Al-Shabaab Militants Shell Ethiopian...
# 181681  "Cop, 2 others killed in bomb blasts in Mindan...
# 181682  "Ascoli, a building destined for migrants goes...
# 181683  "Highlights: Pakistan Pashto Press 02 January ...
# 181684                                                NaN
# 181685                                                NaN
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 181671  "Daesh gunmen kill 3 in northern Iraq: Police,...
# 181672  "Kashmir gunbattle ends after 16 hrs, body of ...
# 181673  "Bombing Kills At Least 17 At Funeral In Easte...
# 181674                                                NaN
# 181675  "Two die in Mogadishu bomb attack," Xinhua Gen...
# 181676                                                NaN
# 181677  "Philippines: Highlights of Terrorist, Counter...
# 181678                                                NaN
# 181679                                                NaN
# 181680                                                NaN
# 181681  "Cop killed, 7 injured in Maguindanao IED blas...
# 181682                                                NaN
# 181683                                                NaN
# 181684                                                NaN
# 181685                                                NaN
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 181671  START Primary Collection        0         1        0       1      NaN
# 181672  START Primary Collection        1         1        0       1      NaN
# 181673  START Primary Collection        0         1        0       1      NaN
# 181674  START Primary Collection        0         1        0       1      NaN
# 181675  START Primary Collection        0         1        1       1      NaN
# 181676  START Primary Collection        0         0        0       0      NaN
# 181677  START Primary Collection        0         0        0       0      NaN
# 181678  START Primary Collection       -9        -9        0      -9      NaN
# 181679  START Primary Collection        0         1        0       1      NaN
# 181680  START Primary Collection        0         1        1       1      NaN
# 181681  START Primary Collection        0         0        0       0      NaN
# 181682  START Primary Collection       -9        -9        0      -9      NaN
# 181683  START Primary Collection        0         0        0       0      NaN
# 181684  START Primary Collection        0         0        0       0      NaN
# 181685  START Primary Collection       -9        -9        0      -9      NaN
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [20 rows x 135 columns]

# %%
data.isnull()
# Out:
#         eventid  iyear  imonth   iday  approxdate  extended  resolution  \
# 0         False  False   False  False        True     False        True
# 1         False  False   False  False        True     False        True
# 2         False  False   False  False        True     False        True
# 3         False  False   False  False        True     False        True
# 4         False  False   False  False        True     False        True
# ...         ...    ...     ...    ...         ...       ...         ...
# 181686    False  False   False  False        True     False        True
# 181687    False  False   False  False        True     False        True
# 181688    False  False   False  False        True     False        True
# 181689    False  False   False  False        True     False        True
# 181690    False  False   False  False        True     False        True
#
#         country  country_txt  region  ...  addnotes  scite1  scite2  scite3  \
# 0         False        False   False  ...      True    True    True    True
# 1         False        False   False  ...      True    True    True    True
# 2         False        False   False  ...      True    True    True    True
# 3         False        False   False  ...      True    True    True    True
# 4         False        False   False  ...      True    True    True    True
# ...         ...          ...     ...  ...       ...     ...     ...     ...
# 181686    False        False   False  ...      True   False   False   False
# 181687    False        False   False  ...      True   False   False   False
# 181688    False        False   False  ...      True   False    True    True
# 181689    False        False   False  ...      True   False    True    True
# 181690    False        False   False  ...      True   False   False    True
#
#         dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY  related
# 0          False    False     False     False    False     True
# 1          False    False     False     False    False     True
# 2          False    False     False     False    False     True
# 3          False    False     False     False    False     True
# 4          False    False     False     False    False     True
# ...          ...      ...       ...       ...      ...      ...
# 181686     False    False     False     False    False     True
# 181687     False    False     False     False    False     True
# 181688     False    False     False     False    False     True
# 181689     False    False     False     False    False     True
# 181690     False    False     False     False    False     True
#
# [181691 rows x 135 columns]

# %%
data.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
data.info
# Out:
# <bound method DataFrame.info of              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# 0            58  Dominican Republic       2  ...      NaN
# 1           130              Mexico       1  ...      NaN
# 2           160         Philippines       5  ...      NaN
# 3            78              Greece       8  ...      NaN
# 4           101               Japan       4  ...      NaN
# ...         ...                 ...     ...  ...      ...
# 181686      182             Somalia      11  ...      NaN
# 181687      200               Syria      10  ...      NaN
# 181688      160         Philippines       5  ...      NaN
# 181689       92               India       6  ...      NaN
# 181690      160         Philippines       5  ...      NaN
#
#                                                    scite1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0                           PGIS        0         0        0       0      NaN
# 1                           PGIS        0         1        1       1      NaN
# 2                           PGIS       -9        -9        1       1      NaN
# 3                           PGIS       -9        -9        1       1      NaN
# 4                           PGIS       -9        -9        1       1      NaN
# ...                          ...      ...       ...      ...     ...      ...
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [181691 rows x 135 columns]>

# %%
data.describe
# Out:
# <bound method NDFrame.describe of              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# 0            58  Dominican Republic       2  ...      NaN
# 1           130              Mexico       1  ...      NaN
# 2           160         Philippines       5  ...      NaN
# 3            78              Greece       8  ...      NaN
# 4           101               Japan       4  ...      NaN
# ...         ...                 ...     ...  ...      ...
# 181686      182             Somalia      11  ...      NaN
# 181687      200               Syria      10  ...      NaN
# 181688      160         Philippines       5  ...      NaN
# 181689       92               India       6  ...      NaN
# 181690      160         Philippines       5  ...      NaN
#
#                                                    scite1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0                           PGIS        0         0        0       0      NaN
# 1                           PGIS        0         1        1       1      NaN
# 2                           PGIS       -9        -9        1       1      NaN
# 3                           PGIS       -9        -9        1       1      NaN
# 4                           PGIS       -9        -9        1       1      NaN
# ...                          ...      ...       ...      ...     ...      ...
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [181691 rows x 135 columns]>

# %%
data.ndim
# Out:
# 2

# %%
data.shape
# Out:
# (181691, 135)

# %%
data.size
# Out:
# 24528285

# %%
data.index
# Out:
# RangeIndex(start=0, stop=181691, step=1)

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
plt.hist(data['iyear'])
plt.title('Histogram for Terrorism attack year wise.')
plt.xlabel('Year Of Terrorism attack')
plt.ylabel('Number of terrorism attack')
plt.show()

# %%
plt.hist(data['imonth'],color='red')
plt.title('Histogram for terrorism attack month wise.')
plt.xlabel('Month Of Terrorism attack')
plt.ylabel('Number of terrorism attack')
plt.show()

# %%
plt.hist(data['iday'],color='pink')
plt.title('Histogram for terrorism attack day wise.')
plt.xlabel('Day Of Terrorism attack')
plt.ylabel('Number of terrorism attack')
plt.show()

# %%
plt.figure(figsize=(10,5))
ax = sns.countplot(x='iyear',data=data,palette='crest')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
plt.title('Terrorist Attacks during tenure of 1970-2017 globally',size=20)
plt.ylabel('Attack')
# Out:
# Text(0, 0.5, 'Attack')

# %%
plt.figure(figsize=(10,5))
ax = sns.countplot(x='imonth',data=data,palette='crest')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
plt.title('Terrorist Attacks month wise globally',size=20)
plt.ylabel('Attack')
# Out:
# Text(0, 0.5, 'Attack')

# %%
plt.figure(figsize=(10,5))
ax = sns.countplot(x='iday',data=data,palette='crest')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
plt.title('Terrorist Attacks day wise globally',size=20)
plt.ylabel('Attack')
# Out:
# Text(0, 0.5, 'Attack')

# %%
plt.figure(figsize=(60,5))
ax = sns.countplot(x='country_txt',data=data,palette='bright')
ax.set_xticklabels(ax.get_xticklabels(), rotation=60, ha="right")
plt.title('Terrorist Attacks month wise globally',size=20)
plt.ylabel('Attack')
# Out:
# Text(0, 0.5, 'Attack')

# %%
plt.figure(figsize=(60,5))
ax = sns.countplot(x='country',data=data,palette='bright')
ax.set_xticklabels(ax.get_xticklabels(), rotation=60, ha="right")
plt.title('Terrorist Attacks month wise globally',size=20)
plt.ylabel('Attack')
# Out:
# Text(0, 0.5, 'Attack')

# %%
plt.figure(figsize=(60,5))
ax = sns.countplot(x='region',data=data,palette='bright')
ax.set_xticklabels(ax.get_xticklabels(), rotation=60, ha="right")
plt.title('Terrorist Attacks month wise globally',size=20)
plt.ylabel('Attack')
# Out:
# Text(0, 0.5, 'Attack')

# %%
plt.figure(figsize=(20,50))
sns.boxplot(x=data['iyear'],y=data['country_txt'])
# Out:
# <Axes: xlabel='iyear', ylabel='country_txt'>

# %%
pd.crosstab(data.iyear, data.region_txt).plot(kind='area',stacked=False,figsize=(20,10))
plt.title('Terrorist Activities depending on region',fontsize=25)
plt.ylabel('Number of Attacks',fontsize=20)
plt.xlabel("Year of Attack",fontsize=20)
plt.show()

# %%
data1 = data[['iyear', 'nkill', 'nwound']].copy()

data1 = data1.groupby(by=['iyear']).sum()

fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(8, 8))

axs[0].plot(data.index, data['nkill'], color='red', linewidth=2)
axs[0].set_title('Distribution of People Died by Year', fontsize=14)
axs[0].set_xlabel('Year', fontsize=12)
axs[0].set_ylabel('Number of People Died', fontsize=12)

axs[1].plot(data.index, data['nwound'], color='green', linewidth=2)
axs[1].set_title('Distribution of People Injured by Year', fontsize=14)
axs[1].set_xlabel('Year', fontsize=12)
axs[1].set_ylabel('Number of People Injured', fontsize=12)

plt.subplots_adjust(hspace=0.4)

plt.show()

# %%
data1 = data[['iyear','nkill']].groupby(['iyear']).sum()
fig, ax4 = plt.subplots(figsize=(20,10))
data1.plot(kind='bar',alpha=0.7,ax=ax4)
plt.xticks(rotation = 50)
plt.title("People Died Due To Attack",fontsize=25)
plt.ylabel("Number of killed peope",fontsize=20)
plt.xlabel('Year',fontsize=20)
top_side = ax4.spines["top"]
top_side.set_visible(False)
right_side = ax4.spines["right"]
right_side.set_visible(False)

# %%
city_counts = data['city'].value_counts().to_frame().sort_values('city', axis=0, ascending=False).head(10)

fig, ax = plt.subplots(figsize=(12, 6))

ax.bar(city_counts.index, city_counts['city'], color=['cyan'], width=0.5)

ax.set_title('Top 10 Cities with Highest Number of Terrorist Attacks', fontsize=16)
ax.set_xlabel('City Name', fontsize=14)
ax.set_ylabel('Number of Attacks', fontsize=14)

ax.tick_params(axis='both', labelsize=12)
ax.set_xticklabels(city_counts.index, rotation=45, ha='right')

for i, v in enumerate(city_counts['city']):
    ax.text(i - 0.1, v + 50, str(v), fontsize=12)

ax.grid(True, linestyle='--', linewidth=0.5, alpha=0.6)

plt.show()
# Out:
# <ipython-input-29-01699824fedd>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(city_counts.index, rotation=45, ha='right')

# %%
attack_counts = data['attacktype1_txt'].value_counts()
fig, ax = plt.subplots(figsize=(12, 6))
ax.bar(attack_counts.index, attack_counts.values, color='orange', width=0.5)

ax.set_title('Number of Terrorist Attacks by Attack Type', fontsize=16)
ax.set_xlabel('Attack Type', fontsize=14)
ax.set_ylabel('Number of Attacks', fontsize=14)

ax.tick_params(axis='both', labelsize=12)

ax.set_xticklabels(attack_counts.index, rotation=60, ha='right')

for i, v in enumerate(attack_counts.values):
    ax.text(i - 0.15, v + 50, str(v), fontsize=12)

ax.grid(True, linestyle='--', linewidth=0.5, alpha=0.6)

plt.show()
# Out:
# <ipython-input-30-88ac991aaf2f>:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(attack_counts.index, rotation=60, ha='right')

# %%
data2 = data[['attacktype1_txt','nkill']].groupby(['attacktype1_txt']).sum()

fig, ax = plt.subplots(figsize=(10, 5))

ax.bar(data1.index, data1['nkill'], color='red')

ax.set_title('Number of People Killed by Attack Type', fontsize=16)
ax.set_xlabel('Attack Type', fontsize=14)
ax.set_ylabel('Number of People Killed', fontsize=14)

ax.tick_params(axis='both', labelsize=12)

ax.set_xticklabels(data1.index, rotation=45, ha='right')

for i, v in enumerate(data1['nkill']):
    ax.text(i - 0.1, v + 50, str(v), fontsize=12)

ax.grid(True, linestyle='--', linewidth=0.5, alpha=0.6)

plt.show()
# Out:
# <ipython-input-31-be00514e0946>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(data1.index, rotation=45, ha='right')

# %%
data3 = data[['gname','nkill']].groupby(['gname']).sum()

data3 = data3.sort_values('nkill', ascending=False)[:10]

fig, ax = plt.subplots(figsize=(12, 6))

ax.barh(data3.index, data3['nkill'], color='red')

ax.set_title('Top 10 Terrorist Groups by Number of People Killed', fontsize=16)
ax.set_xlabel('Number of People Killed', fontsize=14)
ax.set_ylabel('Terrorist Group Name', fontsize=14)

ax.tick_params(axis='both', labelsize=12)
for i, v in enumerate(data3['nkill']):
    ax.text(v + 50, i - 0.1, str(v), fontsize=12)

ax.grid(True, linestyle='--', linewidth=0.5, alpha=0.6)

plt.show()

# %%
group_counts = data['gname'].value_counts().to_frame().drop('Unknown').head(10)

fig, ax = plt.subplots(figsize=(12, 6))

ax.barh(group_counts.index, group_counts['gname'], color='purple')

ax.set_title('Top 10 Terrorist Groups by Number of Attacks', fontsize=16)
ax.set_xlabel('Number of Attacks', fontsize=14)
ax.set_ylabel('Terrorist Group', fontsize=14)

ax.tick_params(axis='both', labelsize=12)

for i, v in enumerate(group_counts['gname']):
    ax.text(v + 50, i - 0.1, str(v), fontsize=12)

ax.grid(True, linestyle='--', linewidth=0.5, alpha=0.6)

plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

countries = data.country_txt.dropna(False)

plt.subplots(figsize=(10, 10))
wordcloud = WordCloud(background_color='white', width=512, height=384).generate(' '.join(countries))
plt.axis('off')
plt.imshow(wordcloud)
plt.title('Word Cloud of Countries', fontsize=16)  # Adjust the title
plt.show()
# Out:
# <ipython-input-34-ccd88722b38f>:4: FutureWarning: In a future version of pandas all arguments of Series.dropna will be keyword-only.
#   countries = data.country_txt.dropna(False)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

attack_types = data.attacktype1_txt.dropna(False)

plt.subplots(figsize=(10, 10))
wordcloud = WordCloud(background_color='white', width=512, height=384).generate(' '.join(attack_types))
plt.axis('off')
plt.imshow(wordcloud)
plt.title('Word Cloud of Attack Types', fontsize=16)  # Adjust the title
plt.show()
# Out:
# <ipython-input-35-66ae62ca4eb4>:4: FutureWarning: In a future version of pandas all arguments of Series.dropna will be keyword-only.
#   attack_types = data.attacktype1_txt.dropna(False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

labels = ['Bombing/Explosion', 'Armed Assault', 'Assassination',
          'Hostage Taking (Kidnapping)', 'Facility/Infrastructure Attack', 'Others']

colors = sns.color_palette('pastel')[0:6]

# Calculate the percentage of each attack type
attack_type_percentages = [10, 20, 15, 5, 30, 20]

# Create pie chart
plt.figure(figsize=(10, 10))
plt.title('Distribution of Attack Types')

# Add explode parameter to emphasize a specific slice (optional)
explode = (0, 0.1, 0, 0, 0, 0)  # Explode the "Armed Assault" slice

plt.pie(attack_type_percentages, labels=labels, colors=colors, explode=explode, autopct='%.0f%%')

plt.axis('equal')  # Ensure the pie chart is circular
plt.show()

# %%
#Preparing the data for analysis
Pakistan = data[data.country_txt == 'Pakistan']
Pakistan_cities = Pakistan.groupby(by='city',as_index=False).count().sort_values(by='eventid',ascending=False).iloc[:5,]

Pakistan_suicide_size = Pakistan['suicide'].sum() / len(Pakistan)
labels = ['Suicide', 'Not Suicide']

Pakistan_year = Pakistan.groupby(by='iyear', as_index=False).sum().loc[:, ['iyear', 'nkill']]

Pakistan_weapon = Pakistan.groupby(by='weapsubtype2_txt',as_index=False).count().sort_values(by='eventid',ascending=False).iloc[:,:2]
Pakistan_attack_type = Pakistan.groupby(by = 'attacktype1_txt', as_index = False).count().sort_values(by = 'eventid', ascending = False).iloc[:,:2]
# Out:
# <ipython-input-37-bf51a211b4d4>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   Pakistan_cities = Pakistan.groupby(by='city',as_index=False).count().sort_values(by='eventid',ascending=False).iloc[:5,]
# <ipython-input-37-bf51a211b4d4>:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Pakistan_year = Pakistan.groupby(by='iyear', as_index=False).sum().loc[:, ['iyear', 'nkill']]
# <ipython-input-37-bf51a211b4d4>:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   Pakistan_weapon = Pakistan.groupby(by='weapsubtype2_txt',as_index=False).count().sort_values(by='eventid',ascending=False).iloc[:,:2]
# <ipython-input-37-bf51a211b4d4>:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   Pakistan_attack_type = Pakistan.groupby(by = 'attacktype1_txt', as_index = False).count().sort_values(by = 'eventid', ascending = False).iloc[:,:2]

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))

# Plot 1 - Top 5 terrorism cities
sns.barplot(x='eventid', y='city', data=Pakistan_cities, ci=None, ax=axs[0, 0], palette='Set3')
axs[0, 0].set_title(f'Top 5 Cities in Pakistan with Most Terrorism Occurrences')
axs[0, 0].set_ylabel('City')
axs[0, 0].set_xlabel('Number of Occurrences')

# Plot 2 - Weapon Types
sns.countplot(x='weapsubtype2_txt', data=Pakistan_weapon, ax=axs[0, 1], palette='viridis')
axs[0, 1].set_xticklabels(axs[0, 1].get_xticklabels(), rotation=90)
axs[0, 1].set_xlabel('Weapon Type')
axs[0, 1].set_ylabel('Count')
axs[0, 1].set_title('Weapon Types Used in Attacks')

# Plot 3 - Victims through the years
sns.lineplot(x='iyear', y='nkill', data=Pakistan_year, ax=axs[1, 0], color='darkorange')
axs[1, 0].set_xlim([1970, 2017])
axs[1, 0].set_title('Number of Terrorism Victims in Pakistan Over Time')
axs[1, 0].set_xlabel('Year')
axs[1, 0].set_ylabel('Number of Victims')

# Plot 4 - Attack Types
sns.barplot(x='attacktype1_txt', y='eventid', data=Pakistan_attack_type, ci=None, ax=axs[1, 1], palette='muted')
axs[1, 1].set_xticklabels(axs[1, 1].get_xticklabels(), rotation=60)
axs[1, 1].set_xlabel('Attack Type')
axs[1, 1].set_ylabel('Count')
axs[1, 1].set_title('Types of Attacks in Pakistan')

plt.suptitle('Terrorism Analysis in Pakistan between 1970 and 2017', size=16)
plt.subplots_adjust(top=0.90, hspace=2)  # Adjust the value of hspace as needed
plt.show()
# Out:
# <ipython-input-38-fbc53187bf35>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='eventid', y='city', data=Pakistan_cities, ci=None, ax=axs[0, 0], palette='Set3')
# <ipython-input-38-fbc53187bf35>:24: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='attacktype1_txt', y='eventid', data=Pakistan_attack_type, ci=None, ax=axs[1, 1], palette='muted')

# %% [markdown]
# # As a security/defense analyst,try to find out the hot zone of terrorism.

# %% [markdown]
# **-> As a security or defense analyst, looking at the above data analytical technniques, we can conclude that "Middle East and North Africa(MENA)" is the hot zone where most number of terrorist attacks have happened in the past.**

# %% [markdown]
# # What all security issues and insights you can derive by EDA?

# %% [markdown]
# **There has been a notable increase in terrorist incidents globally over the past few decades, indicating an ongoing threat that requires continued efforts to counter it. However, terrorism is not evenly distributed across the world, with certain regions experiencing greater concentrations of activity due to factors like political instability and socioeconomic grievances. Terrorist tactics have also evolved over time, shifting from larger, coordinated attacks to smaller, decentralized ones like lone-wolf or small-cell operations. These attacks often result in significant loss of life, injuries, psychological trauma, displacement, and economic disruption. Terrorism is motivated by various ideologies, including religious extremism, separatism, ethnonationalism, and political ideologies, making it crucial for effective counterterrorism strategies to understand these underlying motivations. Governments and international organizations have implemented various measures to combat terrorism, including intelligence sharing, law enforcement cooperation, military operations, counter-radicalization programs, and addressing root causes like poverty and marginalization. Long-term prevention and resilience require building resilient societies that promote good governance, protect human rights, address socio-economic disparities, and foster inclusive societies that discourage extremist ideologies.**
